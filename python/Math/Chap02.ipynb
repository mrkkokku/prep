# %%
from matplotlib import pyplot as plt

x_numbers = [1, 2, 3]
y_numbers = [2, 4, 6]

plt.plot(x_numbers, y_numbers)
# Out:
# 여기 출력되는 object가 graph의 실제 정보를 담은 객체

# %%
# Marking Point 추가하기

plt.plot(x_numbers, y_numbers, marker='o')

# %%
plt.plot(x_numbers, y_numbers, 'x')
