# %%
# 야후 파이낸스는 데이터가 좀 불량하다고 한다.
# 네이버 일별 시세 스크랩하는게 가장 합리적 판단일 것 같고,
# 스크랩 데이터는 DB에 저장해서 활용하자

# 야후 파이낸스와 네이버 금융의 데이터를 비교해보자
# 수치만으로 봤을 때 보다, 시각화하여 보면 몰랐던 걸 발견할 수 있을 것이다

# 야후 파이낸스의 종가, 수정종가, 거래량을 그래프로 그려 파악해보자 (현대차로)

'''
추가 정보 : matplotlib의 pyplot 쓸때 모든 input들을 df들을 to_numpy해서 넣어 줘야함
관련하여 아래의 코드를 저 아래의 실제 수행코드 변환했다

from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()
import matplotlib.pyplot as plt

df = pdr.get_data_yahoo('005380.KS', start='2017-01-01')

plt.figure(figsize=(9, 6))
plt.subplot(2, 1, 1) # 2행 1열 에서 첫번째 영역을 택한다는 뜻
plt.title('Hyundai Motors (Yahoo Finance)')
plt.plot(df.index, df['Close'], 'c', label='Adj Close') # c는 cyan + 실선을 뜻함
plt.plot(df.index, df['Adj Close'], 'b--', label='Adj Close') # b--는 파란색 점선을 뜻함
plt.legend(loc='best')
plt.subplot(2, 1, 2)
plt.bar(df.index, df['Volume'], color='g', label='Volume') # 거래량을 bar차트로 그린다
plt.legend(loc='best')
plt.show()

'''

from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()
import matplotlib.pyplot as plt

df = pdr.get_data_yahoo('005380.KS', start='2017-01-01')

plt.figure(figsize=(9, 6))
plt.subplot(2, 1, 1) # 2행 1열 에서 첫번째 영역을 택한다는 뜻
plt.title('Hyundai Motors (Yahoo Finance)')
plt.plot(df.index.to_numpy(), df['Close'].to_numpy(), 'c', label='Adj Close') # c는 cyan + 실선을 뜻함
plt.plot(df.index.to_numpy(), df['Adj Close'].to_numpy(), 'b--', label='Adj Close') # b--는 파란색 점선을 뜻함
plt.legend(loc='best')
plt.subplot(2, 1, 2)
plt.bar(df.index.to_numpy(), df['Volume'].to_numpy(), color='g', label='Volume') # 거래량을 bar차트로 그린다
plt.legend(loc='best')
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
