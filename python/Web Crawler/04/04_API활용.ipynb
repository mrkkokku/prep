# %%
# 크롤링 막은 사이트들은 API를 제공 해주기도 하는데 그걸 이용해보자
# 기술문서 확인 필요

from bs4 import BeautifulSoup  
from urllib.request import urlopen
import serviceKey as sKey

# 아파트매매 실거래 (국토교통부)
endpoint = 'https://apis.data.go.kr/1613000/RTMSDataSvcAptTrade/getRTMSDataSvcAptTrade?'
serviceKey = sKey.serviceKey()
numOfRows = '9999'
pageNo = '1'

lawdCd = '31110'
dealYmd = '202507'

url = endpoint + 'serviceKey=' + serviceKey + '&numOfRows=' + numOfRows + '&pageNo=' + pageNo + '&LAWD_CD=' + lawdCd + '&DEAL_YMD=' + dealYmd

print(url)
# Out:
# https://apis.data.go.kr/1613000/RTMSDataSvcAptTrade/getRTMSDataSvcAptTrade?serviceKey=GiuzRMxXs6LyoR0Ckg%2Fe2ED%2BCBvKKBk84nCPSd9Z6ocnxh9tSf2qjDz0laxz2lulLt5jDvEFOvtFXw54ym%2FDXg%3D%3D&numOfRows=9999&pageNo=1&LAWD_CD=31110&DEAL_YMD=202507

# %%
html = urlopen(url)
bs_obj = BeautifulSoup(html, "html.parser")

print(bs_obj)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="yes"?><response><header><resultcode>000</resultcode><resultmsg>OK</resultmsg></header><body><items><item><aptdong> </aptdong><aptnm>우정I'PARK</aptnm><buildyear>2010</buildyear><buyergbn>개인</buyergbn><cdealday> </cdealday><cdealtype> </cdealtype><dealamount>68,000</dealamount><dealday>16</dealday><dealmonth>7</dealmonth><dealyear>2025</dealyear><dealinggbn>중개거래</dealinggbn><estateagentsggnm>울산 중구</estateagentsggnm><excluusear>110.5254</excluusear><floor>11</floor><jibun>689</jibun><landleaseholdgbn>N</landleaseholdgbn><rgstdate> </rgstdate><sggcd>31110</sggcd><slergbn>개인</slergbn><umdnm>우정동</umdnm></item><item><aptdong> </aptdong><aptnm>우정혁신도시푸르지오</aptnm><buildyear>2013</buildyear><buyergbn>개인</buyergbn><cdealday> </cdealday><cdealtype> </cdealtype><dealamount>48,300</dealamount><dealday>15</dealday><dealmonth>7</dealmonth><dealyear>2025</dealyear><dealinggbn>중개거래</dealinggbn><estateagentsggnm>울산 중구</estateagentsggnm><excluusear>75.986</excluusear><floor>9</floor><jibun>260</jibun><landleaseholdgbn>N</landleaseholdgbn><rgstdate> </rgstdate><sggcd>31110</sggcd><slergbn>개인</slergbn><umdnm>유곡동</umdnm></item><item><aptdong> </aptdong><aptnm>에일린의뜰3차</aptnm><buildyear>2014</buildyear><buyergbn>개인</buyergbn><cdealday> </cdealday><cdealtype> </cdealtype><dealamount>61,300</dealamount><dealday>2</dealday><dealmonth>7</dealmonth><dealyear>2025</dealyear><dealinggbn>중개거래</dealinggbn><estateagentsggnm>울산 중구</estateagentsggnm><excluusear>99.8419</excluusear><floor>12</floor><jibun>271-2</jibun><landleaseholdgbn>N</landleaseholdgbn><rgstdate> </rgstdate><sggcd>31110</sggcd><slergbn>개인</slergbn><umdnm>유곡동</umdnm></item><item><aptdong> </aptdong><aptnm>태화강엑소디움</aptnm><buildyear>2010</buildyear><buyergbn>개인</buyergbn><cdealday> </cdealday><cdealtype> </cdealtype><dealamount>61,000</dealamount><dealday>9</dealday><dealmonth>7</dealmonth><dealyear>2025</dealyear><dealinggbn>중개거래</dealinggbn><estateagentsggnm>울산 중구</estateagentsggnm><excluusear>128.07</excluusear><floor>11</floor><jibun>82-1</jibun><landleaseholdgbn>N</landleaseholdgbn><rgstdate> </rgstdate><sggcd>31110</sggcd><slergbn>개인</slergbn><umdnm>옥교동</umdnm></item><item><aptdong> </aptdong><aptnm>에일린의뜰3차</aptnm><buildyear>2014</buildyear><buyergbn>개인</buyergbn><cdealday> </cdealday><cdealtype> </cdealtype><dealamount>58,200</dealamount><dealday>15</dealday><dealmonth>7</dealmonth><dealyear>2025</dealyear><dealinggbn>중개거래</dealinggbn><estateagentsggnm>울산 북구, 울산 중구</estateagentsggnm><excluusear>99.8419</excluusear><floor>11</floor><jibun>271-2</jibun><landleaseholdgbn>N</landleaseholdgbn><rgstdate> </rgstdate><sggcd>31110</sggcd><slergbn>개인</slergbn><umdnm>유곡동</umdnm></item><item><aptdong> </aptdong><aptnm>태화강엑소디움</aptnm><buildyear>2010</buildyear><buyergbn>개인</buyergbn><cdealday> </cdealday><cdealtype> </cdealtype><dealamount>115,000</dealamount><dealday>4</dealday><dealmonth>7</dealmonth><dealyear>2025</dealyear><dealinggbn>직거래</dealinggbn><estateagentsggnm> </estateagentsggnm><excluusear>168.77</excluusear><floor>53</floor><jibun>82-1</jibun><landleaseholdgbn>N</landleaseholdgbn><rgstdate> </rgstdate><sggcd>31110</sggcd><slergbn>개인</slergbn><umdnm>옥교동</umdnm></item><item><aptdong> </aptdong><aptnm>복산아이파크</aptnm><buildyear>2017</buildyear><buyergbn>개인</buyergbn><cdealday> </cdealday><cdealtype> </cdealtype><dealamount>40,500</dealamount><dealday>14</dealday><dealmonth>7</dealmonth><dealyear>2025</dealyear><dealinggbn>중개거래</dealinggbn><estateagentsggnm>울산 중구</estateagentsggnm><excluusear>59.84</excluusear><floor>3</floor><jibun>776</jibun><landleaseholdgbn>N</landleaseholdgbn><rgstdate> </rgstdate><sggcd>31110</sggcd><slergbn>개인</slergbn><umdnm>복산동</umdnm></item><item><aptdong> </aptdong><aptnm>우정I'PARK</aptnm><buildyear>2010</buildyear><buyergbn>개인</buyergbn><cdealday> </cdealday><cdealtype> </cdealtype><dealamount>67,400</dealamount><dealday>14</dealday><dealmonth>7</dealmonth><dealyear>2025</dealyear><dealinggbn>중개거래</dealinggbn><estateagen ...
